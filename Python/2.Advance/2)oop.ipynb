# %% [markdown]
# ## 🧩 Challenge:

# %%
class Book:
    """Create a Book class"""
    def __init__(self, title, author, year):    #is a constructor -- it's run when we creates the object -- Attributes
        self.title = title          # Saves the value into a object's memory (all of three)
        self.author = author
        self.year = year

    def description(self):      # is a method that use self.title,etc.., to build the message.
        return f"The book {self.title} by {self.author}, published in {self.year}."

libro = Book("100$ M offert", "Alex Hormozi", 2021)  # creates the object
print(libro.description())  # shows the result on screen: print()  -- libro.description(): calls the method.

# %%
class Movie:
    """Movie Class"""

    def __init__(self, title, director, year):
        self.title = title
        self.director = director
        self.year = year

    def is_classic(self):
        if self.year <= 2000:
            return f"The movie {self.title} is made before the year 2000"
        else:
            return f"The movie {self.title} is made after the year 2000"
        
    def description(self):
        return f"The movie {self.title} directed by {self.director}, released in {self.year}"
    
movie1 = Movie("Matrix", "Wachowski", 1999)
movie2 = Movie("Avatar", "y", 2012)


print(movie1.description())
print(movie2.description())

print(movie1.is_classic())
print(movie2.is_classic())

# %%
class Movie:
    """Create a movie"""
    def __init__(self, title, director, year):
        self.title = title
        self.director = director
        self.year = year
    
    def is_classic(self):
        """Returns True if the movie is from year 2000 or earlier."""
        return self.year < 2000
    
    def description(self):
        """Returns a description of the movie."""
        return f"The movie {self.title} directed by {self.director}, released in {self.year}"
    
    def __str__(self):
        """Makes the object printable using the description method."""
        return self.description()

#Create movie instances:
movie1 = Movie("Matrix", "Wachoswski", 1999)
movie2 = Movie("Avatar", "James Cameron", 2012)

#Print description using __str__()
print(movie1)
print(movie2)

#Check if they are classics
if movie1.is_classic():
    print(f"🎬 '{movie1.title}' is a classic movie.")
else:
    print(f"🎬 '{movie1.title}' is a modern movie")

if movie2.is_classic():
    print(f"🎬 '{movie2.title}' is a classic movie.")
else:
    print(f"🎬 '{movie2.title}' is a modern movie")

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self. year = year
    
    def is_new_model(self):
        return self.year < 2022

    def description(self):
        return f"The car is a {self.brand}, model {self.model} made in {self.year}."

    def __str__(self):
        return self.description()
    
#Create car    
car1 = Car("Tesla", "Y", 2022)
car2 = Car("Porche", "Macan 4s", 2025)

#show
print(car1.description())
print(car2.description())

#condition
if car1.is_new_model > 2018:
    print(f"This car {car1.brand} is after 2018")
else:
    print(f"This car {car1.brand} is before 2018")

if car2.is_new_model > 2018:
    print(f"This car {car2.brand} is after 2018")
else:
    print(f"This car {car2.brand} is before 2018")

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self. year = year
    
    def is_new_model(self):
        return self.year > 2022 # Returns new models after 2022

    def description(self):
        return f"The car is a {self.brand}, model {self.model} made in {self.year}."

    def __str__(self):
        return self.description()
    
#Create car    
car1 = Car("Tesla", "Y", 2022)
car2 = Car("Porche", "Macan 4s", 2025)

#show car descriptions
print(car1.description()) # calls __str__()
print(car2.description())

#condition
if car1.is_new_model():
    print(f"This car {car1.brand} is after 2022")
else:
    print(f"This car {car1.brand} is an old model (before 2022 or earlier.)")

if car2.is_new_model():
    print(f"This car {car2.brand} is after 2022")
else:
    print(f"This car {car2.brand} is an old model (before 2022 or earlier.)")

# %% [markdown]
# ## 🐛Bug-Fix Challenge:

# %%
class Robot:
    def __init__(self, name, power):
        self.name = name
        self.power = power
    
    def speak(self):
        return f"I am {self.name}, with power level {self.power}"
    
    def __str__(self):
        return self.speak()

# Create a robot    
robot1 = Robot("Optimus Pride", 1000)

# Method call
print(robot1.speak())   #Correct way to print the message from speak()

#Or use __str__ implicitly
print(robot1)              # This will automatically call __str__()

# %%
class Hero: # Not correct
   
    """Create a Hero"""
    def __init__(self, name, superpower, strength):
        self.name = name
        self.superpower = superpower
        self.strength = strength
    
    def description(self):
        return f"Hi, my name is {self.name}. My power is {self.superpower} and my strength {self.strength}"
    
    def hero_phrase(self):
        return f"I'm not yet strong enough, but i don't gonna give up. I will be the strongesth hero."
    
    def hero_strength(self):
        return self.strength > 75
    
    def __str__(self):
        return self.hero_phrase
    
    def __str__(self):
        return self.description
    
#Create a hero:
weak = Hero("Luis", "don't give up", 61)

#Hero description
print(weak.hero_phrase())

#Hero phrase
print(weak.hero_phrase())

# %%
class Hero:
    """Create a Hero"""

    def __init__(self, name, superpower, strength):
        self.name = name
        self.superpower = superpower
        self.strength = strength
    
    def description(self):
        return f"Hi, my name is {self.name}. My power is {self.superpower} and my strength is {self.strength}"
    
    def hero_phrase(self):
        return f"I'm not yet strong enough, but i won't give up. I will becomethe strongest hero ever!"
    
    def is_strong(self):
        return self.strength > 70
    
    def __str__(self):
        return self.description()
    
# Create a hero
my_hero = Hero("Damarta", "dreamer", 61)

# Print description
print(my_hero.description())

# Print motivation phrase
print(my_hero.hero_phrase())

# Check if hero is strong
if my_hero.is_strong():
    print(f"🦸‍♂️ Damarta is a strong hero.")
else:
    print(f"🧍‍♂️ Luis still needs to train.")

# %%
"""Bug-fix challenge"""
class Heroes():
    def __init__(self, name, superpower, strength):
        self.name = name
        self.superpower = superpower
        self.strength = strength
    
    def description(self):
        return f"🦸‍♂️ Hi my name is {self.name}. My superpower is {self.superpower} and my strength level is {self.strength}"

    def is_strong(self):
        return self.strength > 69

    def hero_phrase(self):
        return f"I gonna be the strongest and happy hero."
    
    def hero_phrase2(self):
        return f"Dream Big and believe in yourself. Pain is only a part of you, embrace pain."
    
    def __str__(self):
        return self.description()
    
# Create a Hero:
hero1 = Heroes("Luis", "dream big", 45)
hero2 = Heroes("Damarta", "unbreakcaboel", 99)

# Print Hero information
print(hero1)
print(hero2.description())

# Print Hero Phrase:
print(hero1.hero_phrase())
print(hero2.hero_phrase2())

# Ask if hero is strong and print: 
if hero1.is_strong():
    print("💪 I'm becoming stronger.\n")
else:
    print(f"🧱 I'm not strong enough.")

if hero2.is_strong():
    print("💪 I'm becoming stronger.\n")
else:
    print(f"🧱 I'm not strong enough.")

# %%
class Heroes():
    def __init__(self, name, superpower, strength):
        self.name = name
        self.superpower = superpower
        self.strength = strength
    
    def description(self):
        return f"🦸‍♂️ Hero: {self.name} | Power: {self.superpower} | Strength: {self.strength}"
    
    def is_strong(self):
        return self.strength > 75
    
    def __str__(self):
        return self.description()
    
# List of Heroes:
heroes = [
    Heroes("Damarta", "Fire control", 80),
    Heroes("Venus", "Hyper burk", 55),
    Heroes("Kai", "Flash", 70)
]

# Show info:
for hero in heroes:
    print(hero.description())
    
    if hero.is_strong():
        print("💪 This hero is strong.\n")
    else:
        print("🧱 This hero is building his strongnest.\n")

# %%
class Hero: ## 🦸‍♂️ Define the Hero Class
    """Represents a hero with a name, superpower, and strength."""

    def __init__(self, name, power, strength):
        self.name_hero = name
        self.super_power = power
        self.strength = strength

    def description(self):
        return f"🧬 Hero: {self.name_hero}\n💥 Superpower: {self.super_power}\n💪 Strength: {self.strength}"
    
    def hero_phrase(self):
        if self.strength > 90:
            return "🔥 'I am unstoppable. My strength knows no limits!'"
        elif self.strength >= 75:
            return "⚡ 'I've trained hard and I'm ready for anything. I protect the weak and stand tall!'"
        else:
            return "🔄 'I'm not yet strong enough, but I won't give up. I will be the strongest hero.'"
    
    def is_strong(self):
        return self.strength >= 75
    
    def __str__(self):
        return self.description()

# Creates a list of heroes:
heroes = [
    Hero("Damarta", "Fire control", 100),
    Hero("Venus", "Hyper Burk", 60),
    Hero("Kai", "Flash", 75),
    Hero("Luis", "Dream", 60)
]

# Show hero details + phrases + Strength evaluation:
for hero in heroes:
    print("="*80)

    # Show description:
    print(hero) # is the same if you use [ print(hero.description()) ] ; because you use __str__(self)
    
    # Show hero phrase:
    print(hero.hero_phrase())

    # Strength check:
    if hero.is_strong():
        print("💪 This hero is Strong!\n")
    else:
        print("🧱 This hero is still building their strength.\n")

# %%
class Heroes:
    def __init__(self, name, superpower, strength):
        self.name = name
        self.superpower = superpower
        self.strength = strength

    def description(self):
        return f"Hi, my name is {self.name}. My superpower is {self.superpower} and my strength level is {self.strength}."

    def is_strong(self):
        return self.strength > 69

    def hero_phrase(self):
        return "I'm gonna be the strongest and happy hero."

    def hero_phrase2(self):
        return "Dream big and believe in yourself. Pain is only a part of you, embrace pain."

    def __str__(self):
        return self.description()


# Create a Hero:
hero1 = Heroes("Luis", "Dream Big", 45)
hero2 = Heroes("Damarta", "Unbreakable", 99)

# Print Hero information
print(hero1)
print(hero2)

# Print Hero Phrases
print(hero1.hero_phrase())
print(hero2.hero_phrase2())

# Check strength
if hero1.is_strong():
    print("💪 I'm becoming stronger!")
else:
    print("😓 I'm not strong enough yet.")

if hero2.is_strong():
    print("💪 I'm becoming stronger!")
else:
    print("😓 I'm not strong enough yet.")

# %%
class Hero:
    def __init__(self, name, power, strength):
        self.name = name
        self.power = power
        self.strength = strength

h1 = Hero("Kai", "Flash", 70)

# %% [markdown]
# ## The four Pillars of OOP

# %%
#Abstraction
def CoffeMachine():

    def start(self):
        self.__boil_water()
        self.__grind_beans()
        print("☕ Your coffee is ready!")
    
    def __boil_water(self):
        print("Boiling water...")
    
    def __grind_beans(self):
        print("Grinding beans...")

# %%
# Encapsulation
class BankAccount():
    def __init__(self, balance):
        self.__balance = balance # private attribute

    def deposit(self, amount):
        self.__balance += amount
    
    def get_balance(self):
        return self.__balance

# %%
#Inheritance
class Animal:
    def speak(self):
        print("I make a sound.")

class Dog(Animal):
    def speak(self):
        print("🐶 Woof!")

my_dog = Dog()
my_dog.speak()

# %%
#Polymorphism
class Cat:
    def speak(self):
        return "🐱 Meow"
    
class Dog:
    def speak(self):
        return "🐶 Woof"
    
animals = [Cat(), Dog()]

for animal in animals:
    print(animal.speak())

# %% [markdown]
# ## Abstraction

# %%
class CoffeMachine():

    def __init__(self): # Initializes the machine with water and coffe beans.
        self.water = 100
        self.beans = 50

    def __heating_water(self):      # These are private methods (note the  __name): meaning they can't be accessed from outside. They are part of the internal process.
        print("Heating water...")

    def __grinding_beans(self):     # private method
        print("Grinding beans...")

    def __pouring_coffe(self):          # private method
        print("Pouring coffe...")

    def make_coffe(self):                   # This is the public method that users will call. It uses the private methods behind the scenes.
        if self.water >= 20 and self.beans >= 10:
            self.__heating_water()
            self.__grinding_beans()
            self.__pouring_coffe()
            self.water -= 20
            self.beans -=10
            print("☕ Coffee is ready!")
        else:
            print("Not enough resources to make coffe.")

# Use the class
machine = CoffeMachine()
machine.make_coffe()        # This is the only method exposed to the user. The complexity of how coffe is made is abstracted away.

# %%
class CoffeeMachine:
    def __init__(self):
        self.water = 1000
        self.beans = 100

    def __heating_water(self):
        print("Heating water...")

    def __grinding_beans(self):
        print("Grinding beans...")

    def __brew_coffee(self, coffee_type):
        print(f"Brewing your {coffee_type}...")

    def make_coffee(self):
        coffee_type = input("Which coffee do you want? (espresso or americano): ").lower()

        if coffee_type == "espresso":
            required_water = 50
            required_beans = 10
        elif coffee_type == "americano":
            required_water = 100
            required_beans = 25
        else:
            print("❌ Sorry, we don't have that type.")
            return

        if self.water >= required_water and self.beans >= required_beans:
            self.__heating_water()
            self.__grinding_beans()
            self.__brew_coffee(coffee_type)

            self.water -= required_water
            self.beans -= required_beans

            print(f"✅ Your {coffee_type} is ready!")
        else:
            print("❌ Not enough resources. Please refill.")

    def refill(self):
        self.water += 500
        self.beans += 50
        print("🔄 Machine refilled!")

# Test use
machine = CoffeeMachine()
machine.make_coffee()
machine.refill()

# %%
class EspressoMachine():
    """Simulates an espresso machine that uses water and coffee beans."""

    def __init__(self):
        """Initialize machine with full resources."""
        self.water = 1000  # ml
        self.beans = 100   # grams

    # Internal steps (used only inside the class)
    def __heating_water(self):
        print(" 🔥 Heating water...")

    def __grinding_beans(self):
        print(" 🌀 Grinding beans...")

    def __brew_coffee(self, coffee_type):
        print(f" ☕ Brewing your {coffee_type.title()}...")

    def make_coffee(self):
        """Ask user what type of coffee they want, then prepare it."""
        coffee_type = input("\nWhich coffee do you want? (espresso or americano): ").lower()

        if coffee_type == "espresso":
            required_water = 50
            required_beans = 10
        elif coffee_type == "americano":
            required_water = 100
            required_beans = 25
        else:
            print("❌ Sorry, we don't have that type of coffee.")
            return

        if self.water >= required_water and self.beans >= required_beans:
            print()
            self.__heating_water()
            self.__grinding_beans()
            self.__brew_coffee(coffee_type)

            # Subtract used resources
            self.water -= required_water
            self.beans -= required_beans

            print(f"✅ Your {coffee_type.title()} is ready!\n")
        else:
            print("❌ Not enough resources. Please refill.\n")

    def refill(self):
        """Refill machine if resources are below 20%."""
        if self.water <= 200 or self.beans <= 20:
            self.water += 500
            self.beans += 50
            print("🔄 Machine refilled!\n")
        else:
            print("ℹ️  Water and beans are enough. No need to refill.\n")

    def status(self):
        """Display current resource levels."""
        print(f"💧 Water: {self.water}ml | 🌱 Beans: {self.beans}g")


# --- Use the machine ---
machine = EspressoMachine()

# 1. Check status
print("🔎 Initial Machine Status:")
machine.status()

# 2. Make coffee
machine.make_coffee()

# 3. Try refill
machine.refill()

# 4. Final status
print("🔎 Final Machine Status:")
machine.status()

# %% [markdown]
# ## Encapsulation

# %%
class BankAccount():
     
    def __init__(self):
        self.__balance = 0  # Creates a private variable to hold the balance. ⛔ It cannot be acessed directly outside the class -- this is a encapsulation in action.

    def deposit(self, amount):  # is a public method to safely add money.

        if amount > 0:  # check if amount is greater than 0 || if is valid, add it to __balance
            self.__balance += amount
            print(f"Deposited: ${amount}")

        else:
            print("Inavalid deposit amount.")   # Otherwise, shows an error message.
    
    def withdraw(self, amount):     # Public Method: used to subtract money. || Only works if you have enough money, if it is not enough show an error.

        if amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ${amount}")
        
        else:
            print("Not enough funds.")

    def check_balance(self):        # A simple method that shows your balance.  || It gives controlled access to the private variable __balance.
        print(f"Current Balance: ${self.__balance}")

# Create an object of BankAccount:
account = BankAccount()

# Deposit:  (Calls the deposit() method to add $250.000)
account.deposit(250000)     

# Withdraw:     (Withdraws $50000 from the account (if balance is enough))
account.withdraw(50000)

# Check account:        (prints the current balance)
account.check_balance()

# Try to access directly to the account:
# Error: print(account.__balance)

# %%
class BankAccount:
    # Constructor: runs when you create a new BankAccount
    def __init__(self):
        self.__balance = 0  # private attribute (encapsulated)

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount  # access and update private balance
            print(f"💰 Deposited: ${amount}")
        else:
            print("❌ Invalid deposit amount.")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount <= self.__balance:  # only allow if enough funds
            self.__balance -= amount
            print(f"💸 Withdrawn: ${amount}")
        else:
            print("🚫 Not enough funds.")

    # Method to check balance
    def check_balance(self):
        print(f"🧾 Current Balance: ${self.__balance}")

# Create a new bank account
account = BankAccount()

# Deposit money
account.deposit(1000)

# Withdraw some money
account.withdraw(40)

# Check balance
account.check_balance()

# ❌ Trying to access private attribute directly:
# print(account.__balance)  # This will raise an AttributeError

# %%
class Student():

    def __init__(self, name):
        self.name = name    # public attribute
        self.__grade = 0    # private attribute (encapsulated)

    def set_grade(self, value):
        """ Sets the grade if it is valid (0-100) """

        if 0 <= value <= 100:
            self.__grade = value
            print(f"Grade set to {value} for {self.name}.")

        else:
            print("Invalid grade. Must be between 0 and 100.")
    
    def get_grade(self):
        """Return the current grade."""
        print(f"{self.name}'s grade is {self.__grade}")

# create objetct:
studen_a = Student("Luis")
# Add grade
studen_a.set_grade(80)
# Show grade:
studen_a.get_grade()

# %%
class BjjStudent():

    def __init__(self, name):
        self.name = name
        self.__grade = "white belt"
    
    def set_grade(self, value):
        allowed_grades = ["white belt", "blue belt", "purple belt", "brown belt", "black belt"]

        if value.lower() in allowed_grades:
            self.__grade = value.lower()
            print(f"🥋Grade set to {value.title()} for {self.name}.")

        else:
            print(f"Invalid grade. Must be one of:", ", ".join(allowed_grades))

    def get_grade(self):
        print(f"📘{self.name.title()}'s current belt is: {self.__grade.title()}")

# Create object
student1 = BjjStudent("Luis")
# Add grade
student1.set_grade("purple belt")
# Show Grade
student1.get_grade()

# %%
class Student():

    def __init__(self, name):
        self.name = name
        self.__grade = 0
    
    def set_grade(self, value):

        if 0 <= value <= 100:
            self.__grade = value
            print(f"Grade set to {value} for {self.name}")

        else:
            print(f"Invalid grade. Must be between 0 and 100.")
    
    def get_grade(self):
        print(f" {self.name.title()}'s grade is {self.__grade}")

# creat:
student1 = Student("Luis")
# set:
student1.set_grade(50)
# get:
student1.get_grade()
# Out:
# Grade set to 50 for Luis
#  Luis's grade is 50
